# %% [markdown]
# # Competition-colonization_trade-off
#
# Классическая модель Competition-colonization_trade-off. Реализация по статье Murrell David J., Law Richard. Heteromyopia and the spatial coexistence of similar competitors \// Ecology Letters. 2003. Т.6, №1. c. 48–59. URL: http://dx.doi.org/10.1046/j.1461-0248.2003.00397.x.
#
#
#
# Competition-colonization trade-off - это механизм, при котором один вид обладает более сильными конкурентными свойствами, а другой - более высокой способностью к распространению. Мы реализуем этот эффект путем регулирования двух ключевых параметров: дисперсии ядра рождения одного вида $\sigma_2^m$ и силы конкурентного воздействия другого $d'_{21}$.
#
# В своей работе D. J. Murrell и R. Law показали зависимость между этими двумя параметрами (Figure 5). Поэтому проанализируем полученные результаты.
#
# Изначально закрепим параметры для обоих видов:
#
# $$b_1 = b_2 = 0.4, \quad d_1 = d_2 = 0.2, \quad d'_{11} = d'_{22} = d'_{12} = 0.001,$$
# $$\sigma_1^m = 0.04, \quad \sigma^w_{11} = \sigma^w_{12} = \sigma^w_{21} = \sigma^w_{22} = 0.04.$$
#
# ## Вид 1 выживает, вид 2 вымирает CCTO
#
# Для этого возьмем параметры $d'_{21} = 0.0008$ и $\sigma_2^m = 0.04$.
#
# Получается, что у нас все параметры между видами одинаковые, кроме $d'_{12}$ и $d'_{21}$, мы получили, что вид 2 влияет на вид 1 слабее, потому что $0.0008 < 0.001$, поэтому вид 1 вытесняет вид 2. На видео также можно увидеть, что вид 2 вымирает, а вид 1 равномерно распределяется по всей области моделирования.
#
# ## Вид 2 выживает, вид 1 вымирает CCTO
#
# Теперь возьмем параметры $d'_{21} = 0.0008$ и $\sigma_2^m = 0.1$.
#
# То есть мы увеличили дисперсию ядра рождения вида больше, чем в 2 раза, поэтому он получил преимущество в конкуренции. На видео также можно увидеть, что вид 2 почти сразу вымирает, а вид 1 равномерно распределен по всей области моделирования.
#
# ## Оба вида выживают CCTO
#
# Попробуем взять параметры $d'_{21} = 0.0003$ и $\sigma_2^m = 0.1$.
#
# Получается, что мы уменьшили силу межвидовой конкуренции, при действии $d'_{21} = 0.0008$ вид 1 вымирал, а при действии $d'_{21} = 0.0003$ мы получили, что вид 1 может уживаться с видом 2. На видео также можно увидеть, что вид 2 равномерно распределился по всей области, а вид 1 распределен очагами.
#
# Но при этом стоит уменьшить влияние вида 2 на вид 1 до $d'_{21} = 0.0001$, чтобы количество особей вида 1 стало больше, чем вида 2. Мы уменьшили силу межвидовой конкуренции в 3 раза.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import sys
import os
from tqdm import tqdm
from scipy.stats import rayleigh
from matplotlib import animation
from matplotlib.animation import FuncAnimation

# %% [markdown]
# Смотрим на то, где находится корень проекта.

# %%
os.getcwd()
# Out:
# '/home/michael/SBDPP_sim/examples'

# %% [markdown]
# Указываем корень проекта.

# %%
sys.path.append("/home/michael/SBDPP_sim") # ваш путь к папке с проектом
import simulation

# %%
M = 2          # Количество видов
my_seed = 42   # seed для генератора случайных чисел

# %% [markdown]
# Генерируем палитру с фиксированными цветами для M видов и создаем словарь: {вид: цвет}

# %%
colors = sns.color_palette("tab10", M)
color_dict = {i: colors[i] for i in range(M)}

# %% [markdown]
# Инициализируем все параметры и устанавливаем виды в начальные позиции.

# %%
L = 2.0                           # Размер области

birth_rates = [0.4, 0.4]          # Вероятность рождаемости
natural_death_rates = [0.2, 0.2]  # Вероятность естественной смерти

# Вид 1 выживает, вид 2 вымирает
competition_matrix = [            # Матрица конкуренции
    0.001, 0.001,                 # Влияние вида 1 на вид 1 и на вид 2
    0.0008, 0.001                 # Влияние вида 2 на вид 1 и на вид 2
]                               
sigma_m = [0.04, 0.04]            # Радиус распространения потомства

# Вид 2 выживает, вид 1 вымирает (раскомментируйте, если нужно)
# competition_matrix = [
#     0.001, 0.001,     
#     0.0008, 0.001     
# ]                               
# sigma_m = [0.04, 0.1]

# Оба вида выживают (численность вида 2 больше, чем вида 1) (раскомментируйте, если нужно)
# competition_matrix = [
#     0.001, 0.001,     
#     0.0003, 0.001     
# ]                               
# sigma_m = [0.04, 0.1]

# Оба вида выживают (численность вида 1 больше, чем вида 2) (раскомментируйте, если нужно)
# competition_matrix = [
#     0.001, 0.001,     
#     0.0001, 0.001     
# ]                               
# sigma_m = [0.04, 0.04]

sigma_w = np.array([              # Радиус влияния конкуренции
    [0.04, 0.04],
    [0.04, 0.04],
])

def normal_2d_radial(r, sigma):
    return (1 / (2 * np.pi * sigma**2)) * np.exp(-r**2 / (2 * sigma**2))


q_values = np.arange(0, 1.0, 0.001)

birth_inverse_values = []
for i in range(M):
    inverse_vals = rayleigh.ppf(q_values, scale=sigma_m[i])
    birth_inverse_values.append(inverse_vals.tolist())

death_r_values = []
death_density_values = []

for i in range(M):
    r_values_row = []
    density_row = []
    
    for j in range(M):
        r_max = min(10 * sigma_w[i,j], L/2)
        r_vals = np.linspace(0, r_max, 500)
        
        density = normal_2d_radial(r_vals, sigma_w[i, j])
        
        r_values_row.append(r_vals.tolist())
        density_row.append(density.tolist())
    
    death_r_values.append(r_values_row)
    death_density_values.append(density_row)


max_sigma = max(max(sigma_m), np.max(sigma_w))
max_r = min(10 * max_sigma, L/2)

g2 = simulation.PyGrid2(
    M = M,
    areaLen = [L, L],
    cellCount = [50, 50],
    isPeriodic = False,
    birthRates = birth_rates,
    deathRates = natural_death_rates,
    ddMatrix = competition_matrix,
    birthX = [q_values.tolist()] * M,
    birthY = birth_inverse_values,
    deathX_ = death_r_values,
    deathY_ = death_density_values,
    cutoffs = [max_r] * (M * M),
    seed = my_seed,
    rtimeLimit = 7200.0
)

np.random.seed(my_seed)
coordinates = []
for _ in range(M):
    group = [[np.random.uniform(0, L), np.random.uniform(0, L)] for _ in range(500)]
    coordinates.append(group)

g2.placePopulation(coordinates)

# %% [markdown]
# Производим симуляцию.

# %%
data = []
for t in (pbar := tqdm(range(1500))):
    for c in range(g2.get_num_cells()):
        for n in range(M):
            coords = g2.get_cell_coords(c, n)
            for x, y in coords:
                data.append([t, x, y, n])
    g2.run_for(1)
    pbar.set_description(f"Population: {g2.total_population}, Progress")

df = pd.DataFrame(columns = ['time', 'x', 'y', 's'], data = data)
# display(df.set_index('time'))
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]
# Population: 518, Progress: 100%|██████████| 1500/1500 [00:14<00:00, 103.70it/s]

# %% [markdown]
# Выводим график первых моментов.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

for n in range(M):
    density = df[df['s'] == n].groupby('time').size() / (L ** 2)  
    median_density = density.median()

    ax.plot(density.index, density.values, label=f'Плотность - Вид {n+1}', color=color_dict[n])
    ax.axhline(median_density, linestyle="dashed", color=color_dict[n], alpha=0.7, label=f'Средняя - Вид {n+1}')

ax.legend()
ax.set_xlabel("Время")
ax.set_ylabel("Плотность особей")
ax.set_title("Динамика первых моментов (плотность)")

plt.show()

# %% [markdown]
# По полученным данным создаем видео.

# %%
total_frames = df['time'].nunique()
desired_duration = 60
fps = total_frames / desired_duration

movie_writer = animation.FFMpegWriter(
    fps = fps,
    codec = 'h264',
    bitrate = 2000,
    extra_args = [
        '-vcodec', 'libx264',
        '-pix_fmt', 'yuv420p',
        '-preset', 'medium'
    ]
)

matplotlib.rcParams['animation.ffmpeg_path'] = '/usr/bin/ffmpeg' # путь к ffmpeg

df = df.sort_values('time')
output_file = "Competition-colonization_trade-off_1min.mp4"

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlim(0, L)
ax.set_ylim(0, L)
ax.set_xlabel('x')
ax.set_ylabel('y')
sc = ax.scatter([], [], c=[], s=20, alpha=0.6)

def update(frame):
    current_df = df[df['time'] == frame]
    sc.set_offsets(current_df[['x', 'y']].values)
    sc.set_color([color_dict[s] for s in current_df['s']])
    ax.set_title(f"Time: {frame}")
    return sc,

ani = FuncAnimation(fig, update, frames=df['time'].nunique(), blit=True)
progress_callback = tqdm(total=total_frames, desc='Creating 1-minute video')

def on_frame(current_frame, *args):
    progress_callback.update(1)

ani.save(output_file, writer=movie_writer, progress_callback=on_frame)
progress_callback.close()

print(f"Animation saved as {output_file} (duration: 1 minute)")
plt.close(fig)
